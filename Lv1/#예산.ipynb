# %% [markdown]
# S사에서는 각 부서에 필요한 물품을 지원해 주기 위해 부서별로 물품을 구매하는데 필요한 금액을 조사했습니다. 그러나, 전체 예산이 정해져 있기 때문에 모든 부서의 물품을 구매해 줄 수는 없습니다. 그래서 최대한 많은 부서의 물품을 구매해 줄 수 있도록 하려고 합니다.
#
# 물품을 구매해 줄 때는 각 부서가 신청한 금액만큼을 모두 지원해 줘야 합니다. 예를 들어 1,000원을 신청한 부서에는 정확히 1,000원을 지원해야 하며, 1,000원보다 적은 금액을 지원해 줄 수는 없습니다.
#
# 부서별로 신청한 금액이 들어있는 배열 d와 예산 budget이 매개변수로 주어질 때, 최대 몇 개의 부서에 물품을 지원할 수 있는지 return 하도록 solution 함수를 완성해주세요.

# %%
# 확인
# 조합을 만들 것.
from itertools import combinations
budget = 10
d = [2,2,3,3]
dict = {}
for r in range(1,len(d)+1):
    # 해당 d의 문자길이 별 조합 생성
    combinations_list = list(combinations(d, r))
    # dict의 key는 문자길이(즉, 부서의 개수), value를 해당 문자길이 조합 별 합으로 설정
    # 조건 : budget 이하 + len(sums)가 있는 경우만!
    sums = [sum(com) for com in combinations_list if sum(com)<=budget]
    if len(sums) != 0:
        dict[r] = sums


# 최대로 만들 수 있는 조합의 key 출력하기.
max(dict.keys())
# Out:
# 4

# %%
# 정답
def solution(d, budget):
    from itertools import combinations
    dict = {}
    for r in range(1,len(d)+1):
        combinations_list = list(combinations(d, r))
        sums = [sum(com) for com in combinations_list if sum(com)<=budget]
        if len(sums) != 0:
            dict[r] = sums
    return max(dict.keys())

# %%
solution([2,2,3,3],10)
# Out:
# 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 시간초과 문제 발생...
#
# - 조합을 만드는 과정에서 발생하는 건가?
